# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model="openai/gpt-oss-20b",
    temperature=0
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '## Blog Outline  \n**Title:** *Rise of AI in India: From Start‑ups to Smart Cities*  \n\n---\n\n### 1. Introduction  \n- **Hook:** A striking statistic or anecdote (e.g., “India’s AI market is projected to hit $12\u202fbillion by 2025”).  \n- **Purpose:** Explain why the AI boom matters to India’s economy, society, and global standing.  \n- **Roadmap:** Briefly outline the sections that will follow.\n\n---\n\n### 2. Historical Context  \n- **Early Beginnings (1990s‑2000s)**  \n  - First AI research labs (e.g., IITs, CSIR).  \n  - Limited commercial adoption; focus on academia.  \n- **Catalysts for Growth**  \n  - Liberalization of IT sector.  \n  - Rise of data‑driven enterprises.  \n  - Global AI breakthroughs (deep learning, GPUs).  \n\n---\n\n### 3. Current Landscape of AI in India  \n- **Market Size & Growth**  \n  - CAGR, projected valuation, comparison with global peers.  \n- **Key Players**  \n  - **Large Corporations:** Infosys, Wipro, TCS, HCL.  \n  - **Start‑ups & Scale‑ups:** Haptik, Niki.ai, SigTuple, Uniphore.  \n  - **Multinationals with Indian Presence:** Google, Microsoft, Amazon, IBM.  \n- **Geographic Hotspots**  \n  - Bengaluru, Hyderabad, Pune, Chennai, Delhi NCR, and emerging hubs (e.g., Noida, Gurugram).  \n\n---\n\n### 4. Sectors Driving AI Adoption  \n| Sector | AI Applications | Impact | Representative Companies |\n|--------|-----------------|--------|---------------------------|\n| **Healthcare** | Diagnostics, tele‑medicine, drug discovery | Faster, cheaper, remote care | SigTuple, Niramai, Practo |\n| **Agriculture** | Crop monitoring, yield prediction, pest detection | Increased productivity, sustainability | CropIn, Stellapps |\n| **Finance** | Fraud detection, credit scoring, robo‑advisors | Risk reduction, financial inclusion | Razorpay, Paytm, PolicyBazaar |\n| **Retail & E‑commerce** | Personalization, demand forecasting | Higher conversion, inventory optimization | Flipkart, Amazon India |\n| **Manufacturing** | Predictive maintenance, quality control | Reduced downtime, cost savings | Bosch, Siemens India |\n| **Smart Cities & IoT** | Traffic management, energy optimization | Improved urban living | CityMinds, Smart City Mission |\n| **Education** | Adaptive learning, skill assessment | Personalized learning paths | Byju’s, Vedantu |\n\n---\n\n### 5. Government Initiatives & Policy Framework  \n- **National AI Strategy (2018)**  \n  - Vision, objectives, and key focus areas.  \n- **AI for All**  \n  - AI in public services, e‑Governance.  \n- **Funding & Grants**  \n  - AI Fund (₹1,000 crore), Startup India, Atal Innovation Mission.  \n- **Regulatory Landscape**  \n  - Data protection (Personal Data Protection Bill), AI ethics guidelines.  \n- **Public‑Private Partnerships**  \n  - AI labs in universities, industry consortia.  \n\n---\n\n### 6. Academic & Research Ecosystem  \n- **Top Institutions**  \n  - IITs, IISc, NITs, AIIMS, AI research centers.  \n- **Research Themes**  \n  - Natural Language Processing (NLP) for Indian languages, computer vision, robotics.  \n- **Collaborations**  \n  - International partnerships (MIT, Stanford, Tsinghua).  \n- **Talent Pipeline**  \n  - AI courses, MOOCs, hackathons, AI clubs.  \n\n---\n\n### 7. Start‑up Ecosystem & Funding Landscape  \n- **Funding Trends**  \n  - VC inflows, angel investments, corporate venture arms.  \n- **Success Stories**  \n  - Case studies: Haptik (acquired by Microsoft), SigTuple (Series C).  \n- **Challenges**  \n  - Talent scarcity, data access, scaling to enterprise.  \n- **Support Structures**  \n  - Incubators (T-Hub, NASSCOM 10,000 Startups), accelerators, government grants.  \n\n---\n\n### 8. Data & Infrastructure Foundations  \n- **Data Availability**  \n  - Public datasets, open data initiatives, industry data sharing.  \n- **Cloud & Edge Computing**  \n  - AWS, Azure, Google Cloud, local providers (Tata Communications).  \n- **Hardware & Chips**  \n  - Indian chip makers  ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline
# **Title:** *Rise of AI in India: From Start‑ups to Smart Cities*
#
# ---
#
# ### 1. Introduction
# - **Hook:** A striking statistic or anecdote (e.g., “India’s AI market is projected to hit $12 billion by 2025”).
# - **Purpose:** Explain why the AI boom matters to India’s economy, society, and global standing.
# - **Roadmap:** Briefly outline the sections that will follow.
#
# ---
#
# ### 2. Historical Context
# - **Early Beginnings (1990s‑2000s)**
#   - First AI research labs (e.g., IITs, CSIR).
#   - Limited commercial adoption; focus on academia.
# - **Catalysts for Growth**
#   - Liberalization of IT sector.
#   - Rise of data‑driven enterprises.
#   - Global AI breakthroughs (deep learning, GPUs).
#
# ---
#
# ### 3. Current Landscape of AI in India
# - **Market Size & Growth**
#   - CAGR, projected valuation, comparison with global peers.
# - **Key Players**
#   - **Large Corporations:** Infosys, Wipro, TCS, HCL.
#   - **Start‑ups & Scale‑ups:** Haptik, Niki.ai, SigTuple, Uniphore.
#   - **Multinationals with Indian Presence:** Google, Microsoft, Amazon, IBM.
# - **Geographic Hotspots**
#   - Bengaluru, Hyderabad, Pune, Chennai, Delhi NCR, and emerging hubs (e.g., Noida, Gurugram).
#
# ---
#
# ### 4. Sectors Driving AI Adoption
# | Sector | AI Applications | Impact | Representative Companies |
# |--------|-----------------|--------|---------------------------|
# | **Healthcare** | Diagnostics, tele‑medicine, drug discovery | Faster, cheaper, remote care | SigTuple, Niramai, Practo |
# | **Agriculture** | Crop monitoring, yield prediction, pest detection | Increased productivity, sustainability | CropIn, Stellapps |
# | **Finance** | Fraud detection, credit scoring, robo‑advisors | Risk reduction, financial inclusion | Razorpay, Paytm, PolicyBazaar |
# | **Retail & E‑commerce** | Personalization, demand forecasting | Higher conversion, inventory optimization | Flipkart, Amazon India |
# | **Manufacturing** | Predictive maintenance, quality control | Reduced downtime, cost savings | Bosch, Siemens India |
# | **Smart Cities & IoT** | Traffic management, energy optimization | Improved urban living | CityMinds, Smart City Mission |
# | **Education** | Adaptive learning, skill assessment | Personalized learning paths | Byju’s, Vedantu |
#
# ---
#
# ### 5. Government Initiatives & Policy Framework
# - **National AI Strategy (2018)**
#   - Vision, objectives, and key focus areas.
# - **AI for All**
#   - AI in public services, e‑Governance.
# - **Funding & Grants**
#   - AI Fund (₹1,000 crore), Startup India, Atal Innovation Mission.
# - **Regulatory Landscape**
#   - Data protection (Personal Data Protection Bill), AI ethics guidelines.
# - **Public‑Private Partnerships**
#   - AI labs in universities, industry consortia.
#
# ---
#
# ### 6. Academic & Research Ecosystem
# - **Top Institutions**
#   - IITs, IISc, NITs, AIIMS, AI research centers.
# - **Research Themes**
#   - Natural Language Processing (NLP) for Indian languages, computer vision, robotics.
# - **Collaborations**
#   - International partnerships (MIT, Stanford, Tsinghua).
# - **Talent Pipeline**
#   - AI courses, MOOCs, hackathons, AI clubs.
#
# ---
#
# ### 7. Start‑up Ecosystem & Funding Landscape
# - **Funding Trends**
#   - VC inflows, angel investments, corporate venture arms.
# - **Success Stories**
#   - Case studies: Haptik (acquired by Microsoft), SigTuple (Series C).
# - **Challenges**
#   - Talent scarcity, data access, scaling to enterprise.
# - **Support Structures**
#   - Incubators (T-Hub, NASSCOM 10,000 Startups), accelerators, government grants.
#
# ---
#
# ### 8. Data & Infrastructure Foundations
# - **Data Availability**
#   - Public datasets, open data initiatives, industry data sharing.
# - **Cloud & Edge Computing**
#   - AWS, Azure, Google Cloud, local providers (Tata Communications).
# - **Hardware & Chips**
#   - Indian chip makers (MIPS, VLIW), GPU adoption.
# - **Cybersecurity & Privacy**
#   - Data protection laws, secure data pipelines.
#
# ---
#
# ### 9. Socio‑Economic Impacts
# - **Employment & Skill Development**
#   - AI job creation vs. displacement.
#   - Upskilling programs (NPTEL, Coursera, local bootcamps).
# - **Digital Inclusion**
#   - AI in rural connectivity, low‑cost diagnostics.
# - **Ethical & Social Concerns**
#   - Bias in AI models, algorithmic transparency, job automation.
#
# ---
#
# ### 10. Challenges & Risks
# - **Talent Gap**
#   - Need for data scientists, ML engineers, AI ethicists.
# - **Data Quality & Bias**
#   - Representation of diverse Indian demographics.
# - **Regulatory Uncertainty**
#   - Evolving data protection laws, AI governance.
# - **Infrastructure Bottlenecks**
#   - Power, internet penetration, hardware costs.
#
# ---
#
# ### 11. Future Outlook & Predictions
# - **Market Forecasts**
#   - CAGR, adoption rates across sectors.
# - **Emerging Trends**
#   - Federated learning, AI‑driven policy making, quantum AI.
# - **Strategic Recommendations**
#   - For policymakers, industry leaders, educators.
#
# ---
#
# ### 12. Conclusion
# - **Recap of Key Takeaways**
# - **Call to Action**
#   - Encourage collaboration, investment, and responsible AI practices.
# - **Closing Thought**
#   - Quote from a prominent Indian AI leader or a visionary statement.
#
# ---
#
# ### 13. Suggested Visuals & Media
# - **Infographics**
#   - AI market growth chart, sector adoption heatmap.
# - **Data Tables**
#   - Funding rounds, AI job statistics.
# - **Case Study Snapshots**
#   - Before‑and‑after metrics for a startup or public service.
# - **Video Clip**
#   - Interview with an AI researcher or entrepreneur.
#
# ---
#
# ### 14. References & Further Reading
# - List of reports, academic papers, news articles, and official documents cited.
#
# ---
#
# **Optional Add‑Ons**
# - **Sidebar:** “Top 5 AI Tools Every Indian Startup Should Know.”
# - **Interactive Element:** Poll on readers’ perception of AI in daily life.
# - **Newsletter Sign‑up Prompt** for AI updates.
#
# ---
#
# *This outline provides a comprehensive, structured framework for a blog that covers the rise of AI in India from multiple angles—historical, economic, sectoral, policy, and societal—while offering actionable insights and engaging multimedia suggestions.*

# %%
print(final_state['content'])
# Out:
# # Rise of AI in India: From Start‑ups to Smart Cities
#
# ---
#
# ## 1. Introduction
#
# > **“India’s AI market is projected to hit $12 billion by 2025.”**
# > — *NASSCOM AI Report 2023*
#
# The numbers are staggering, but the story behind them is even more compelling. Artificial Intelligence (AI) is no longer a niche research curiosity; it is a strategic engine that is reshaping India’s economy, society, and its position on the global stage. From Bengaluru’s buzzing start‑up incubators to Delhi’s smart‑city pilots, AI is weaving itself into the fabric of everyday life.
#
# **Why does this boom matter?**
# - **Economic Growth:** AI can add up to 1.5 % to India’s GDP by 2030, according to a McKinsey study.
# - **Social Impact:** AI-powered diagnostics are bringing quality healthcare to remote villages; AI chatbots are bridging language gaps in education.
# - **Global Standing:** With a talent pool of 1.5 million AI researchers and a growing ecosystem of unicorns, India is poised to become a global AI hub.
#
# **Roadmap of this blog**
# 1. Historical context of AI in India
# 2. Current market landscape
# 3. Sectors driving adoption
# 4. Government initiatives & policy framework
# 5. Academic & research ecosystem
# 6. Start‑up ecosystem & funding
# 7. Data & infrastructure foundations
# 8. Socio‑economic impacts
# 9. Challenges & risks
# 10. Future outlook & predictions
# 11. Conclusion & call to action
#
# Let’s dive in.
#
# ---
#
# ## 2. Historical Context
#
# ### Early Beginnings (1990s‑2000s)
# - **Academic Roots:** The first AI research labs sprouted in premier institutions—**IIT Bombay (1992)**, **IIT Madras (1995)**, and **CSIR’s National Physical Laboratory (1998)**.
# - **Focus:** Primarily theoretical work—expert systems, knowledge representation, and early machine learning.
# - **Commercial Adoption:** Minimal; AI was largely confined to academia and a handful of defense projects.
#
# ### Catalysts for Growth
# | Catalyst | Impact |
# |----------|--------|
# | **IT Liberalization (1991)** | Opened the market to foreign investment, creating a culture of innovation. |
# | **Rise of Data‑Driven Enterprises** | Companies like Infosys and Wipro began exploring analytics, laying groundwork for AI. |
# | **Global AI Breakthroughs** | Deep learning frameworks (TensorFlow, PyTorch) and GPU acceleration made AI accessible. |
#
# ---
#
# ## 3. Current Landscape of AI in India
#
# ### Market Size & Growth
# - **2023 Valuation:** $4.5 billion (NASSCOM).
# - **CAGR (2023‑2028):** 28 % projected.
# - **Global Comparison:** India is the 3rd largest AI market after the US and China, but still 10× smaller than the US.
#
# ### Key Players
#
# | Category | Companies |
# |----------|-----------|
# | **Large Corporations** | Infosys, Wipro, TCS, HCL Technologies, Tech Mahindra |
# | **Start‑ups & Scale‑ups** | Haptik, Niki.ai, SigTuple, Uniphore, Locus, ZestMoney |
# | **Multinationals with Indian Presence** | Google, Microsoft, Amazon, IBM, NVIDIA, Intel |
#
# ### Geographic Hotspots
# - **Bengaluru** – “Silicon Valley of India”
# - **Hyderabad** – IT parks + biotech cluster
# - **Pune** – Manufacturing + software services
# - **Chennai** – Automotive + IT
# - **Delhi NCR** – Policy hub + fintech
# - **Emerging Hubs** – Noida, Gurugram, Kochi, Jaipur
#
# ---
#
# ## 4. Sectors Driving AI Adoption
#
# | Sector | AI Applications | Impact | Representative Companies |
# |--------|-----------------|--------|---------------------------|
# | **Healthcare** | Diagnostics (image analysis), tele‑medicine, drug discovery | Faster, cheaper, remote care | SigTuple, Niramai, Practo |
# | **Agriculture** | Crop monitoring, yield prediction, pest detection | Increased productivity, sustainability | CropIn, Stellapps |
# | **Finance** | Fraud detection, credit scoring, robo‑advisors | Risk reduction, financial inclusion | Razorpay, Paytm, PolicyBazaar |
# | **Retail & E‑commerce** | Personalization, demand forecasting | Higher conversion, inventory optimization | Flipkart, Amazon India |
# | **Manufacturing** | Predictive maintenance, quality control | Reduced downtime, cost savings | Bosch, Siemens India |
# | **Smart Cities & IoT** | Traffic management, energy optimization | Improved urban living | CityMinds, Smart City Mission |
# | **Education** | Adaptive learning, skill assessment | Personalized learning paths | Byju’s, Vedantu |
#
# ---
#
# ## 5. Government Initiatives & Policy Framework
#
# ### National AI Strategy (2018)
# - **Vision:** Position India as a global AI leader by 2030.
# - **Objectives:** Build AI infrastructure, foster talent, promote ethical AI.
# - **Key Focus Areas:** Healthcare, agriculture, smart cities, education, manufacturing.
#
# ### AI for All
# - **Public Services:** AI chatbots for e‑Governance, predictive analytics for disaster management.
# - **E‑Governance:** AI‑driven citizen service portals (e.g., e‑KYC, Aadhaar).
#
# ### Funding & Grants
# - **AI Fund (₹1,000 crore)** – Dedicated to AI research and start‑ups.
# - **Startup India** – Tax incentives, funding, incubation.
# - **Atal Innovation Mission** – Grants for innovation labs.
#
# ### Regulatory Landscape
# - **Personal Data Protection Bill (2023)** – Data privacy framework.
# - **AI Ethics Guidelines (2024)** – Transparency, accountability, fairness.
#
# ### Public‑Private Partnerships
# - **AI Labs in Universities** – e.g., IIT Delhi’s AI Lab, IISc’s AI Research Centre.
# - **Industry Consortia** – NASSCOM AI Council, AI India Initiative.
#
# ---
#
# ## 6. Academic & Research Ecosystem
#
# ### Top Institutions
# - **IITs** (BHU, Bombay, Madras, Kharagpur)
# - **IISc Bangalore**
# - **NITs** (Trichy, Surathkal)
# - **AIIMS** (Delhi)
# - **Centre for Artificial Intelligence & Robotics (CAIR)**
#
# ### Research Themes
# - **NLP for Indian Languages** – Transliteration, sentiment analysis.
# - **Computer Vision** – Satellite imagery, autonomous vehicles.
# - **Robotics** – Agricultural robots, medical robots.
#
# ### Collaborations
# - **MIT, Stanford, Tsinghua** – Joint research projects, faculty exchanges.
# - **Industry Partnerships** – IBM Research India, Microsoft Research India.
#
# ### Talent Pipeline
# - **Courses** – B.Tech AI, M.Tech ML, PhDs.
# - **MOOCs** – NPTEL, Coursera, edX.
# - **Hackathons & AI Clubs** – Hackerearth, Kaggle competitions.
#
# ---
#
# ## 7. Start‑up Ecosystem & Funding Landscape
#
# ### Funding Trends
# - **VC Inflows (2023)** – $1.2 billion in AI start‑ups.
# - **Corporate Venture Arms** – Microsoft’s M12, Infosys’ iON.
# - **Angel Investments** – ₹50 crore per round on average.
#
# ### Success Stories
# - **Haptik** – Acquired by Microsoft for $400 M (2021).
# - **SigTuple** – Series C funding of $30 M (2022).
# - **Uniphore** – $100 M Series B (2021).
#
# ### Challenges
# - **Talent Scarcity** – 70% of AI start‑ups cite lack of skilled engineers.
# - **Data Access** – Proprietary data barriers.
# - **Scaling to Enterprise** – Integration with legacy systems.
#
# ### Support Structures
# - **Incubators** – T‑Hub (Bengaluru), NASSCOM 10,000 Startups (Hyderabad).
# - **Accelerators** – Microsoft for Startups, Google Launchpad.
# - **Government Grants** – Startup India, Atal Innovation Mission.
#
# ---
#
# ## 8. Data & Infrastructure Foundations
#
# ### Data Availability
# - **Public Datasets** – Government open data portals (data.gov.in).
# - **Industry Data Sharing** – Health data consortia, agritech data lakes.
#
# ### Cloud & Edge Computing
# - **Global Providers** – AWS, Azure, Google Cloud.
# - **Local Providers** – Tata Communications, Reliance Jio Cloud.
#
# ### Hardware & Chips
# - **Indian Chip Makers** – MIPS, VLIW, and emerging AI chips from **Tata Consultancy**.
# - **GPU Adoption** – NVIDIA, AMD, and local GPU manufacturing initiatives.
#
# ### Cybersecurity & Privacy
# - **Data Protection Laws** – Personal Data Protection Bill.
# - **Secure Pipelines** – End‑to‑end encryption, federated learning.
#
# ---
#
# ## 9. Socio‑Economic Impacts
#
# ### Employment & Skill Development
# - **Job Creation vs. Dis
